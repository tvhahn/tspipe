# %%
import numpy as np
import pandas as pd
from pathlib import Path
import random
import matplotlib.pyplot as plt
import seaborn as sns
from src.models.utils import load_cnc_features

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_data_dir = Path.cwd().parent.parent / "data"
path_processed_dir1 = Path(Path.cwd().parent.parent / 'data/processed/cnc/cnc_features_comp')
print(path_processed_dir1)

df1 = pd.read_csv(
    path_processed_dir1 / "cnc_features_54_comp.csv",
)

path_processed_dir2 = Path(Path.cwd().parent.parent / 'data/processed/cnc/cnc_features_comp_extra')

df2 = pd.read_csv(
    path_processed_dir2 / "cnc_features_54_comp_extra.csv",
)

# %%
df1 = load_cnc_features(
    path_data_dir, path_processed_dir1, "cnc_features_54_comp.csv", "high_level_labels_MASTER_update2022-08-18_with_case.csv"
)
df1 = df1.sort_values(by=['id']).reset_index(drop=True)
print(df1.shape)
df1.head()
# Out:
# (43679, 756)
#                 id  current__time_reversal_asymmetry_statistic__lag_1  \
# 0  1540298755_54_0                                      -8.086279e+06
# 1  1540298755_54_1                                      -1.170708e+05
# 2  1540298755_54_2                                      -6.492383e+06
# 3  1540298755_54_3                                      -2.596672e+05
# 4  1540298755_54_4                                       1.070022e+05
#
#    current__time_reversal_asymmetry_statistic__lag_2  \
# 0                                      -1.533470e+07
# 1                                      -3.050618e+05
# 2                                      -1.250417e+07
# 3                                      -3.990829e+05
# 4                                       1.629973e+05
#
#    current__time_reversal_asymmetry_statistic__lag_3  current__c3__lag_1  \
# 0                                      -2.303145e+07        7.131262e+09
# ...

# %%
df2 = load_cnc_features(
    path_data_dir, path_processed_dir2, "cnc_features_54_comp_extra.csv", "high_level_labels_MASTER_update2022-08-18_with_case.csv"
)
df2 = df2.sort_values(by=['id']).reset_index(drop=True)
print(df2.shape)
df2.head()
# Out:
# (43679, 773)
#                 id  current__mean_abs_change  current__abs_energy  \
# 0  1540298755_54_0                110.738467         8.305576e+09
# 1  1540298755_54_1                 19.384335         5.800704e+09
# 2  1540298755_54_2                 87.541940         9.282231e+09
# 3  1540298755_54_3                 38.849049         4.431590e+09
# 4  1540298755_54_4                 43.174338         6.461842e+09
#
#    current__mean_change  current__mean_second_derivative_central  \
# 0             -0.629432                                -0.007818
# 1             -0.049512                                -0.000412
# 2             -0.487371                                -0.002027
# 3             -0.119790                                -0.001822
# 4              0.056619                                -0.003871
#
#    current__median  current__mean  current__standard_deviation  \
# 0            963.0    1572.850991                   831.489353
# ...

# %%
feat_select = [
    'current__fft_coefficient__attr_"abs"__coeff_54', 
    'current__value_count__value_1', 
    'current__fft_coefficient__attr_"abs"__coeff_34', 
    'current__fft_coefficient__attr_"imag"__coeff_73', 
    'current__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4', 
    'current__fft_coefficient__attr_"imag"__coeff_46', 
    'current__fft_coefficient__attr_"angle"__coeff_79', 
    'current__fft_coefficient__attr_"angle"__coeff_90', 
    'current__fft_coefficient__attr_"real"__coeff_14', 
    'current__time_reversal_asymmetry_statistic__lag_2'
    ]

# %%
# compare is the "id" column is the same in both dataframes
pd.testing.assert_frame_equal(df1[['id']+feat_select], df2[['id']+feat_select])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/tim/Documents/feat-store/notebooks/scratch/9.0_compare_diff_feat_dataframes.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/tim/Documents/feat-store/notebooks/scratch/9.0_compare_diff_feat_dataframes.ipynb#ch0000008?line=0'>1</a> # compare is the "id" column is the same in both dataframes
# ----> <a href='vscode-notebook-cell:/home/tim/Documents/feat-store/notebooks/scratch/9.0_compare_diff_feat_dataframes.ipynb#ch0000008?line=1'>2</a> pd.testing.assert_frame_equal(df1[['id']], df2[['id', 'id']])
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/featstore/lib/python3.8/site-packages/pandas/_testing/asserters.py:682, in raise_assert_detail(obj, message, left, right, diff, index_values)
#     679 if diff is not None:
#     680     msg += f"\n[diff]: {diff}"
# ...
