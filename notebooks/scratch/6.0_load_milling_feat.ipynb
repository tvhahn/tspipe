# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
path_data_dir = Path.cwd().parent.parent / "data"
print("path_data_dir", path_data_dir)
# Out:
# path_data_dir /home/tim/Documents/feat-store/data

# %%
df = pd.read_csv(path_data_dir / "processed/milling/milling_features_comp_stride64_len1024" / "milling_features_comp_stride64_len1024.csv")

# %%
print("df.shape", df.shape)
df.head()
# Out:
# df.shape (9040, 4510)
#   cut_id  smcac__time_reversal_asymmetry_statistic__lag_1  \
# 0  87_20                                        -0.009862
# 1  87_21                                        -0.014233
# 2  87_22                                        -0.023152
# 3  87_23                                        -0.008329
# 4  87_24                                         0.006926
#
#    smcac__time_reversal_asymmetry_statistic__lag_2  \
# 0                                        -0.008820
# 1                                        -0.006940
# 2                                        -0.024342
# 3                                        -0.001119
# 4                                         0.018749
#
#    smcac__time_reversal_asymmetry_statistic__lag_3  smcac__c3__lag_1  \
# 0                                         0.002745         -0.997182
# 1                                         0.003651         -1.006841
# 2                                        -0.000312         -1.067194
# ...

# %%
df = df.dropna(axis=1)  # drop any columns that have NaNs in them
print("df.shape", df.shape)
# Out:
# df.shape (9040, 4456)

# %%
df = df.dropna(axis=0)  # drop any rows that have NaN values in them
print("df.shape", df.shape)
# Out:
# df.shape (9040, 4456)

# %%
df.head()
# Out:
#   cut_id  smcac__time_reversal_asymmetry_statistic__lag_1  \
# 0  87_20                                        -0.009862
# 1  87_21                                        -0.014233
# 2  87_22                                        -0.023152
# 3  87_23                                        -0.008329
# 4  87_24                                         0.006926
#
#    smcac__time_reversal_asymmetry_statistic__lag_2  \
# 0                                        -0.008820
# 1                                        -0.006940
# 2                                        -0.024342
# 3                                        -0.001119
# 4                                         0.018749
#
#    smcac__time_reversal_asymmetry_statistic__lag_3  smcac__c3__lag_1  \
# 0                                         0.002745         -0.997182
# 1                                         0.003651         -1.006841
# 2                                        -0.000312         -1.067194
# ...
